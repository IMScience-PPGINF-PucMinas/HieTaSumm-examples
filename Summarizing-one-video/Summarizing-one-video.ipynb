# %%
# !pip install higra
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 7.5 MB/s eta 0:00:00
# ...

# %%
# !pip install HieTaSumm
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for HieTaSumm: filename=HieTaSumm-0.0.19-py3-none-any.whl size=9689 sha256=c643f5a439e46978e7ca9af070e5585742b39f631657f2e92645ec7f7372b035
#   Stored in directory: /root/.cache/pip/wheels/e3/43/b9/52b3e0db7be0fba798a43c4b7d0d89616fe1b63f5835dbd992
# Successfully built HieTaSumm
# ...

# %%
from HieTaSumm import HieTaSumm
HieTaSumm()
# Out:
# ------------------------
# ./videos/Cooking.webm/
# ...
# 102967424/102967424 [==============================] - 1s 0us/step
# ----------------------
# Processing video ./summary/Cooking/
# ...
# 1/1 [==============================] - 1s 1s/step
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7e0e6c1e3490> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 1s/step
# ...
